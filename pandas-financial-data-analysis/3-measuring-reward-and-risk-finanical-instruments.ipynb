# %% [markdown]
# Price Changes and Financial Returns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:4f}'.format
plt.style.use('seaborn-v0_8-darkgrid')

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates =["Date"])

# %%
msft
# Out:
#                  MSFT   Returns
# Date
# 2014-10-01  38.880161       NaN
# 2014-10-02  38.761574 -0.003050
# 2014-10-03  39.041103  0.007212
# 2014-10-06  39.041103  0.000000
# 2014-10-07  38.566746 -0.012150
# ...               ...       ...
# 2021-05-24 241.744522  0.022882
# 2021-05-25 242.650650  0.003748
# 2021-05-26 242.428955 -0.000914
# 2021-05-27 240.327469 -0.008668
# 2021-05-28 240.684143  0.001484
#
# [1677 rows x 2 columns]

# %%
msft.MSFT.plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize =13)
plt.show()

# %% [markdown]
# Reward: Positive Returns
# Risk: Volatility of Returns

# %%
msft.describe()
# Out:
#              MSFT     Returns
# count 1677.000000 1676.000000
# mean    99.129514    0.001237
# std     59.766644    0.017240
# min     34.437160   -0.147390
# 25%     48.195683   -0.006110
# 50%     82.674355    0.000962
# 75%    131.331589    0.009110
# max    251.949539    0.142169

# %%
mu =msft.Returns.mean() # athrithmetic mean return -> Reward
mu
# Out:
# np.float64(0.001236732122059186)

# %%
sigma = msft.Returns.std() # standard deviation of returns -> Risk/Volatility
sigma
# Out:
# np.float64(0.017240430775512447)

# %%
np.sqrt(msft.Returns.var())
# Out:
# np.float64(0.017240430775512447)
