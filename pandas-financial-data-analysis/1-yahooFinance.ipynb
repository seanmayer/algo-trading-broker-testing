# %%
# Financial Data Analysis

# %%
import pandas as pd
import yfinance as yf

# %%
start = "2014-10-01"
end = "2021-05-31"

# %%
symbol = "BA", "MSFT", "^DJI", "EURUSD=X", "GC=F", "BTC-USD"

# %%
yf.download(symbol, start, end, multi_level_index=False)
# Out:
# /var/folders/f8/mtg4j9ld7738_4k47b8j8hd40000gn/T/ipykernel_56597/1235008259.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   yf.download(symbol, start, end, multi_level_index=False)
# [*********************100%***********************]  6 of 6 completed
# Price            Close                                                   \
# Ticker              BA       BTC-USD  EURUSD=X         GC=F        MSFT
# Date
# 2014-10-01  108.406662    383.614990  1.262834  1214.599976   38.880169
# 2014-10-02  107.971878    375.071991  1.262419  1214.199951   38.761570
# 2014-10-03  109.876221    359.511993  1.267058  1192.199951   39.041100
# 2014-10-04         NaN    328.865997       NaN          NaN         NaN
# 2014-10-05         NaN    320.510010       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2021-05-26  241.369995  39294.199219  1.224909  1901.300049  242.428955
# ...

# %%
df = yf.download(symbol, start, end, multi_level_index=False)
df
# Out:
# /var/folders/f8/mtg4j9ld7738_4k47b8j8hd40000gn/T/ipykernel_56597/1442495588.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start, end, multi_level_index=False)
# [*********************100%***********************]  6 of 6 completed
# Price            Close                                                   \
# Ticker              BA       BTC-USD  EURUSD=X         GC=F        MSFT
# Date
# 2014-10-01  108.406662    383.614990  1.262834  1214.599976   38.880169
# 2014-10-02  107.971878    375.071991  1.262419  1214.199951   38.761570
# 2014-10-03  109.876221    359.511993  1.267058  1192.199951   39.041100
# 2014-10-04         NaN    328.865997       NaN          NaN         NaN
# 2014-10-05         NaN    320.510010       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2021-05-26  241.369995  39294.199219  1.224909  1901.300049  242.428955
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2434 entries, 2014-10-01 to 2021-05-30
# Freq: D
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, BA)         1677 non-null   float64
#  1   (Close, BTC-USD)    2434 non-null   float64
#  2   (Close, EURUSD=X)   1735 non-null   float64
#  3   (Close, GC=F)       1674 non-null   float64
#  4   (Close, MSFT)       1677 non-null   float64
#  5   (Close, ^DJI)       1677 non-null   float64
#  6   (High, BA)          1677 non-null   float64
#  7   (High, BTC-USD)     2434 non-null   float64
#  8   (High, EURUSD=X)    1735 non-null   float64
#  9   (High, GC=F)        1674 non-null   float64
#  10  (High, MSFT)        1677 non-null   float64
#  11  (High, ^DJI)        1677 non-null   float64
#  12  (Low, BA)           1677 non-null   float64
#  13  (Low, BTC-USD)      2434 non-null   float64
# ...

# %%
symbol = ["BA", "MSFT", "^DJI", "EURUSD=X", "GC=F", "BTC-USD"]

# %%
df = yf.download(symbol,start,end)
df
# Out:
# /var/folders/f8/mtg4j9ld7738_4k47b8j8hd40000gn/T/ipykernel_56597/3849209574.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol,start,end)
# [*********************100%***********************]  6 of 6 completed
# Price            Close                                                   \
# Ticker              BA       BTC-USD  EURUSD=X         GC=F        MSFT
# Date
# 2014-10-01  108.406662    383.614990  1.262834  1214.599976   38.880169
# 2014-10-02  107.971878    375.071991  1.262419  1214.199951   38.761570
# 2014-10-03  109.876221    359.511993  1.267058  1192.199951   39.041100
# 2014-10-04         NaN    328.865997       NaN          NaN         NaN
# 2014-10-05         NaN    320.510010       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2021-05-26  241.369995  39294.199219  1.224909  1901.300049  242.428955
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2434 entries, 2014-10-01 to 2021-05-30
# Freq: D
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, BA)         1677 non-null   float64
#  1   (Close, BTC-USD)    2434 non-null   float64
#  2   (Close, EURUSD=X)   1735 non-null   float64
#  3   (Close, GC=F)       1674 non-null   float64
#  4   (Close, MSFT)       1677 non-null   float64
#  5   (Close, ^DJI)       1677 non-null   float64
#  6   (High, BA)          1677 non-null   float64
#  7   (High, BTC-USD)     2434 non-null   float64
#  8   (High, EURUSD=X)    1735 non-null   float64
#  9   (High, GC=F)        1674 non-null   float64
#  10  (High, MSFT)        1677 non-null   float64
#  11  (High, ^DJI)        1677 non-null   float64
#  12  (Low, BA)           1677 non-null   float64
#  13  (Low, BTC-USD)      2434 non-null   float64
# ...

# %%
df.to_csv("different_assets.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2434 entries, 2014-10-01 to 2021-05-30
# Freq: D
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, BA)         1677 non-null   float64
#  1   (Close, BTC-USD)    2434 non-null   float64
#  2   (Close, EURUSD=X)   1735 non-null   float64
#  3   (Close, GC=F)       1674 non-null   float64
#  4   (Close, MSFT)       1677 non-null   float64
#  5   (Close, ^DJI)       1677 non-null   float64
#  6   (High, BA)          1677 non-null   float64
#  7   (High, BTC-USD)     2434 non-null   float64
#  8   (High, EURUSD=X)    1735 non-null   float64
#  9   (High, GC=F)        1674 non-null   float64
#  10  (High, MSFT)        1677 non-null   float64
#  11  (High, ^DJI)        1677 non-null   float64
#  12  (Low, BA)           1677 non-null   float64
#  13  (Low, BTC-USD)      2434 non-null   float64
# ...

# %%
df.Close
# Out:
# Ticker              BA       BTC-USD  EURUSD=X         GC=F        MSFT  \
# Date
# 2014-10-01  108.406662    383.614990  1.262834  1214.599976   38.880169
# 2014-10-02  107.971878    375.071991  1.262419  1214.199951   38.761570
# 2014-10-03  109.876221    359.511993  1.267058  1192.199951   39.041100
# 2014-10-04         NaN    328.865997       NaN          NaN         NaN
# 2014-10-05         NaN    320.510010       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2021-05-26  241.369995  39294.199219  1.224909  1901.300049  242.428955
# 2021-05-27  250.699997  38436.968750  1.219260  1895.699951  240.327499
# 2021-05-28  247.020004  35697.605469  1.219319  1902.500000  240.684158
# 2021-05-29         NaN  34616.066406       NaN          NaN         NaN
# 2021-05-30         NaN  35678.128906       NaN          NaN         NaN
#
# Ticker              ^DJI
# Date
# 2014-10-01  16804.710938
# 2014-10-02  16801.050781
# ...

# %%
df.loc[:,("Close", "BA")] # Loc is used to select a specific column
# Out:
# Date
# 2014-10-01    108.406662
# 2014-10-02    107.971878
# 2014-10-03    109.876221
# 2014-10-04           NaN
# 2014-10-05           NaN
#                  ...
# 2021-05-26    241.369995
# 2021-05-27    250.699997
# 2021-05-28    247.020004
# 2021-05-29           NaN
# 2021-05-30           NaN
# Freq: D, Name: (Close, BA), Length: 2434, dtype: float64

# %%
df.loc["2015-01-07"] # One day
df.loc["2015-01-07":"2015-01-14"] # One week
df.loc["2015-01-07":"2015-01-14",("Close", "BA")] # One week for BA
df.loc[:,("Close", "BA")]
df.loc[:,("Close", "BA")]
df.loc[:,("Close", "BA")]
df.loc[:,("Close", "BA")]
# Out:
# Date
# 2014-10-01    108.406662
# 2014-10-02    107.971878
# 2014-10-03    109.876221
# 2014-10-04           NaN
# 2014-10-05           NaN
#                  ...
# 2021-05-26    241.369995
# 2021-05-27    250.699997
# 2021-05-28    247.020004
# 2021-05-29           NaN
# 2021-05-30           NaN
# Freq: D, Name: (Close, BA), Length: 2434, dtype: float64

# %%
df.loc["2015"]
# Out:
# Price            Close                                                \
# Ticker              BA     BTC-USD  EURUSD=X         GC=F       MSFT
# Date
# 2015-01-01         NaN  314.248993  1.209863          NaN        NaN
# 2015-01-02  113.657211  315.032013  1.208941  1186.000000  39.858448
# 2015-01-03         NaN  281.082001       NaN          NaN        NaN
# 2015-01-04         NaN  264.195007       NaN          NaN        NaN
# 2015-01-05  112.870087  274.473999  1.194643  1203.900024  39.491917
# ...                ...         ...       ...          ...        ...
# 2015-12-27         NaN  422.822998       NaN          NaN        NaN
# 2015-12-28  129.628296  422.278992  1.096599  1070.500000  48.990410
# 2015-12-29  132.148422  432.983002  1.097526  1077.500000  49.515778
# 2015-12-30  131.305374  426.619995  1.092801  1060.099976  49.305637
# 2015-12-31  129.673126  430.566986  1.093398  1060.300049  48.578873
#
# ...

# %%
df = df.swaplevel(axis = "columns").sort_index(axis = "columns") # Swap the levels of the columns

# %%
df["EURUSD=X"]
# Out:
# Price          Close      High       Low      Open  Volume
# Date
# 2014-10-01  1.262834  1.263999  1.258574  1.262913     0.0
# 2014-10-02  1.262419  1.269050  1.261610  1.262499     0.0
# 2014-10-03  1.267058  1.266994  1.250159  1.266994     0.0
# 2014-10-04       NaN       NaN       NaN       NaN     NaN
# 2014-10-05       NaN       NaN       NaN       NaN     NaN
# ...              ...       ...       ...       ...     ...
# 2021-05-26  1.224909  1.226500  1.220003  1.224890     0.0
# 2021-05-27  1.219260  1.221699  1.217567  1.219036     0.0
# 2021-05-28  1.219319  1.220107  1.213342  1.219274     0.0
# 2021-05-29       NaN       NaN       NaN       NaN     NaN
# 2021-05-30       NaN       NaN       NaN       NaN     NaN
#
# [2434 rows x 5 columns]

# %%
df["BTC-USD"]
# Out:
# Price              Close          High           Low          Open  \
# Date
# 2014-10-01    383.614990    391.378998    380.779999    387.427002
# 2014-10-02    375.071991    385.497009    372.946014    383.988007
# 2014-10-03    359.511993    377.695007    357.859009    375.181000
# 2014-10-04    328.865997    364.487000    325.885986    359.891998
# 2014-10-05    320.510010    341.800995    289.295990    328.915985
# ...                  ...           ...           ...           ...
# 2021-05-26  39294.199219  40782.078125  37905.835938  38392.625000
# 2021-05-27  38436.968750  40379.617188  37247.902344  39316.890625
# 2021-05-28  35697.605469  38856.968750  34779.039062  38507.082031
# 2021-05-29  34616.066406  37234.500000  33693.929688  35684.156250
# 2021-05-30  35678.128906  36400.667969  33520.738281  34607.406250
#
# Price            Volume
# Date
# 2014-10-01     26229400
# 2014-10-02     21777700
# 2014-10-03     30901200
# 2014-10-04     47236500
# ...

# %%
df.swaplevel(axis = "columns").sort_index(axis = "columns")
# Out:
# Price            Close                                                   \
# Ticker              BA       BTC-USD  EURUSD=X         GC=F        MSFT
# Date
# 2014-10-01  108.406662    383.614990  1.262834  1214.599976   38.880169
# 2014-10-02  107.971878    375.071991  1.262419  1214.199951   38.761570
# 2014-10-03  109.876221    359.511993  1.267058  1192.199951   39.041100
# 2014-10-04         NaN    328.865997       NaN          NaN         NaN
# 2014-10-05         NaN    320.510010       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2021-05-26  241.369995  39294.199219  1.224909  1901.300049  242.428955
# 2021-05-27  250.699997  38436.968750  1.219260  1895.699951  240.327499
# 2021-05-28  247.020004  35697.605469  1.219319  1902.500000  240.684158
# 2021-05-29         NaN  34616.066406       NaN          NaN         NaN
# 2021-05-30         NaN  35678.128906       NaN          NaN         NaN
#
# ...

# %%
print(df.columns)
# Out:
# MultiIndex([(      'BA',  'Close'),
#             (      'BA',   'High'),
#             (      'BA',    'Low'),
#             (      'BA',   'Open'),
#             (      'BA', 'Volume'),
#             ( 'BTC-USD',  'Close'),
#             ( 'BTC-USD',   'High'),
#             ( 'BTC-USD',    'Low'),
#             ( 'BTC-USD',   'Open'),
#             ( 'BTC-USD', 'Volume'),
#             ('EURUSD=X',  'Close'),
#             ('EURUSD=X',   'High'),
#             ('EURUSD=X',    'Low'),
#             ('EURUSD=X',   'Open'),
#             ('EURUSD=X', 'Volume'),
#             (    'GC=F',  'Close'),
#             (    'GC=F',   'High'),
#             (    'GC=F',    'Low'),
#             (    'GC=F',   'Open'),
#             (    'GC=F', 'Volume'),
#             (    'MSFT',  'Close'),
#             (    'MSFT',   'High'),
#             (    'MSFT',    'Low'),
#             (    'MSFT',   'Open'),
#             (    'MSFT', 'Volume'),
#             (    '^DJI',  'Close'),
# ...

# %%
close = df.xs('Close', level='Price', axis=1).copy()

# %%
close
# Out:
# Ticker              BA       BTC-USD  EURUSD=X         GC=F        MSFT  \
# Date
# 2014-10-01  108.406662    383.614990  1.262834  1214.599976   38.880169
# 2014-10-02  107.971878    375.071991  1.262419  1214.199951   38.761570
# 2014-10-03  109.876221    359.511993  1.267058  1192.199951   39.041100
# 2014-10-04         NaN    328.865997       NaN          NaN         NaN
# 2014-10-05         NaN    320.510010       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2021-05-26  241.369995  39294.199219  1.224909  1901.300049  242.428955
# 2021-05-27  250.699997  38436.968750  1.219260  1895.699951  240.327499
# 2021-05-28  247.020004  35697.605469  1.219319  1902.500000  240.684158
# 2021-05-29         NaN  34616.066406       NaN          NaN         NaN
# 2021-05-30         NaN  35678.128906       NaN          NaN         NaN
#
# Ticker              ^DJI
# Date
# 2014-10-01  16804.710938
# 2014-10-02  16801.050781
# ...

# %%
close.describe() # Describe the data
# Out:
# Ticker           BA       BTC-USD     EURUSD=X         GC=F         MSFT  \
# count   1677.000000   2434.000000  1735.000000  1674.000000  1677.000000
# mean     219.225303   7613.831432     1.140643  1372.014516    99.129515
# std       95.563916  11611.182396     0.050101   235.715391    59.766645
# min       95.010002    178.102997     1.039047  1050.800049    34.437153
# 25%      128.910004    534.628006     1.105412  1216.549988    48.195709
# 50%      185.100952   4368.375000     1.129995  1283.149963    82.674377
# 75%      326.229980   9205.574951     1.177704  1482.300018   131.331619
# max      430.299988  63503.457031     1.282166  2051.500000   251.949646
#
# Ticker          ^DJI
# count    1677.000000
# mean    23004.372736
# std      4659.921979
# min     15660.179688
# 25%     18086.400391
# 50%     23625.339844
# 75%     26289.980469
# max     34777.761719

# %%
close.BA.dropna().plot(figsize = (15,8), fontsize = 14)
# Out:
# <Axes: xlabel='Date'>

# %%
close.dropna().plot(figsize = (15,8), fontsize = 13)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Normalising Time Series to a Base Value (100)

# %%
close
# Out:
# Ticker              BA       BTC-USD  EURUSD=X         GC=F        MSFT  \
# Date
# 2014-10-01  108.406662    383.614990  1.262834  1214.599976   38.880169
# 2014-10-02  107.971878    375.071991  1.262419  1214.199951   38.761570
# 2014-10-03  109.876221    359.511993  1.267058  1192.199951   39.041100
# 2014-10-04         NaN    328.865997       NaN          NaN         NaN
# 2014-10-05         NaN    320.510010       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2021-05-26  241.369995  39294.199219  1.224909  1901.300049  242.428955
# 2021-05-27  250.699997  38436.968750  1.219260  1895.699951  240.327499
# 2021-05-28  247.020004  35697.605469  1.219319  1902.500000  240.684158
# 2021-05-29         NaN  34616.066406       NaN          NaN         NaN
# 2021-05-30         NaN  35678.128906       NaN          NaN         NaN
#
# Ticker              ^DJI
# Date
# 2014-10-01  16804.710938
# 2014-10-02  16801.050781
# ...

# %%
close.iloc[0,0] # first price of BA
# Out:
# np.float64(108.40666198730469)

# %%
close.BA.div(close.iloc[0,0])
# Out:
# Date
# 2014-10-01    1.000000
# 2014-10-02    0.995989
# 2014-10-03    1.013556
# 2014-10-04         NaN
# 2014-10-05         NaN
#                 ...
# 2021-05-26    2.226524
# 2021-05-27    2.312588
# 2021-05-28    2.278642
# 2021-05-29         NaN
# 2021-05-30         NaN
# Freq: D, Name: BA, Length: 2434, dtype: float64

# %%
norm = close.div(close.iloc[0,0]).mul(100)
norm
# Out:
# Ticker              BA       BTC-USD  EURUSD=X         GC=F        MSFT  \
# Date
# 2014-10-01  100.000000    353.866620  1.164904  1120.410825   35.865110
# 2014-10-02   99.598932    345.986108  1.164522  1120.041821   35.755708
# 2014-10-03  101.355598    331.632749  1.168801  1099.747865   36.013561
# 2014-10-04         NaN    303.363272       NaN          NaN         NaN
# 2014-10-05         NaN    295.655271       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2021-05-26  222.652364  36247.033622  1.129921  1753.859047  223.629204
# 2021-05-27  231.258847  35456.279204  1.124709  1748.693223  221.690711
# 2021-05-28  227.864229  32929.346605  1.124764  1754.965945  222.019712
# 2021-05-29         NaN  31931.678157       NaN          NaN         NaN
# 2021-05-30         NaN  32911.380401       NaN          NaN         NaN
#
# Ticker              ^DJI
# Date
# 2014-10-01  15501.548179
# 2014-10-02  15498.171859
# ...

# %%
norm.dropna().plot(figsize = (15,8), fontsize = 13, logy = True)
# Out:
# <Axes: xlabel='Date'>

# %%
close.to_csv("close.csv")
