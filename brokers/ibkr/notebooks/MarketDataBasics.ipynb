# %% [markdown]
# # Current Market Data
#
# This section demonstrates how to retrieve real-time market data for financial instruments using Interactive Brokers.

# %%
import pandas as pd
from ib_async import *
util.startLoop()

# %%
ib = IB()

# %%
ib.connect()
# Out:
# <IB connected to 127.0.0.1:7497 clientId=1>

# %%
contract = Forex("EURUSD")
contract = ib.qualifyContracts(contract)[0]  # Qualify and get first result
contract
# Out:
# Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD')

# %%
data1 = ib.reqMktData(contract)
data1
# Out:
# Ticker(contract=Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'), defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)

# %%
data1
# Out:
# Ticker(contract=Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'), time=datetime.datetime(2025, 11, 25, 20, 23, 25, 727826, tzinfo=datetime.timezone.utc), timestamp=1764102205.727832, minTick=1e-05, bid=1.15721, bidSize=1000000.0, ask=1.15722, askSize=2500000.0, last=1.15725, lastSize=0.0, lastTimestamp=datetime.datetime(2025, 11, 25, 20, 23, 24, tzinfo=datetime.timezone.utc), prevBid=1.1572, prevBidSize=4400000.0, prevAsk=1.15725, prevAskSize=1500000.0, volume=0.0, high=1.15865, low=1.1512, close=1.1521, ticks=[TickData(time=datetime.datetime(2025, 11, 25, 20, 23, 25, 727826, tzinfo=datetime.timezone.utc), tickType=1, price=1.15721, size=1000000.0), TickData(time=datetime.datetime(2025, 11, 25, 20, 23, 25, 727826, tzinfo=datetime.timezone.utc), tickType=3, price=1.15722, size=2500000.0)], defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)

# %%
data1.ask
# Out:
# 1.15722

# %%
data1.askSize
# Out:
# 2500000.0

# %%
data1.marketPrice()
# Out:
# 1.1571850000000001

# %%
data1.time
# Out:
# datetime.datetime(2025, 11, 25, 20, 23, 31, 431686, tzinfo=datetime.timezone.utc)

# %%
pd.to_datetime(data1.time)
# Out:
# Timestamp('2025-11-25 20:23:31.431686+0000', tz='UTC')

# %%
contract = Stock("AAPL", "SMART", "USD")
contract
# Out:
# Stock(symbol='AAPL', exchange='SMART', currency='USD')

# %%
contract = Forex("EURUSD")
contract = ib.qualifyContracts(contract)[0]  # Qualify and get first result
contract
data2 = ib.reqMktData(contract)
data2
# Out:
# Ticker(contract=Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'), time=datetime.datetime(2025, 11, 25, 20, 23, 34, 739666, tzinfo=datetime.timezone.utc), timestamp=1764102214.739672, minTick=1e-05, bid=1.15718, bidSize=1000000.0, ask=1.15719, askSize=1500000.0, last=1.15715, lastSize=0.0, lastTimestamp=datetime.datetime(2025, 11, 25, 20, 23, 29, tzinfo=datetime.timezone.utc), prevBid=1.15716, prevBidSize=2000000.0, prevAsk=1.15718, prevAskSize=1000000.0, prevLast=1.15725, prevLastSize=0.0, volume=0.0, high=1.15865, low=1.1512, close=1.1521, defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)

# %%
ib.disconnect()
# Out:
# 'Disconnecting from 127.0.0.1:7497, 369 B sent in 12 messages, 26.1 kB received in 585 messages, session time 19.7 s.'
